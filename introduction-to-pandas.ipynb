# %%
import pandas as pd

# %%
cars = pd.Series(["audi","toyotas"])
cars
# Out:
# 0       audi
# 1    toyotas
# dtype: object

# %%
colours = pd.Series(["red","blue"])
colours
# Out:
# 0     red
# 1    blue
# dtype: object

# %%
car = pd.DataFrame({"car name" : cars , "colours": colours})
car
# Out:
#   car name colours
# 0     audi     red
# 1  toyotas    blue

# %%
car_sales = pd.read_csv("car_sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exeported-file.csv" , index = False)

# %%
file = pd.read_csv("exeported-file.csv")
file
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# Describe data

# %%
#attribute 
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 car_sales
#
# NameError: name 'car_sales' is not defined

# %% [markdown]
# viewing and selecting data

# %%
car_sales = pd.read_csv("car-sales.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 car_sales = pd.read_csv("car-sales.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car_sales.csv")

# %% [markdown]
# Viewing and selecting data

# %%
car_sales.head()#it gives the frist five coloumns
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()#fro bottom five rows
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# .loc and .iloc

# %%
animals = pd.Series(["cat","snake"],
                   index=[2,3])
animals
# Out:
# 2      cat
# 3    snake
# dtype: object

# %%
animals.loc[3]  #loc keyword stands for location
# Out:
# 'snake'

# %%
animals.iloc[:1]
# Out:
# 2    cat
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"] , car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
 car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]', '',regex=True).astype(int)

# %%
car_sales['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].hist()

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
seats_column = pd.Series([5,4,5,4,5])
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    4.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    4.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    NaN
# 6   Honda   Blue          45698      4   750000    NaN
# 7   Honda   Blue          54738      4   700000    NaN
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    4.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    4.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    5.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
fuel_economy =[7.5,8.9, 8.9, 9.0, 7.8, 8.9 , 9.0, 7.8, 8.7, 9.0]
car_sales["Fuel per 100kM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    4.0             8.9
# 2  Toyota   Blue          32549      3   700000    5.0             8.9
# 3     BMW  Black          11179      5  2200000    4.0             9.0
# 4  Nissan  White         213095      4   350000    5.0             7.8
# 5  Toyota  Green          99213      4   450000    5.0             8.9
# 6   Honda   Blue          45698      4   750000    5.0             9.0
# 7   Honda   Blue          54738      4   700000    5.0             7.8
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             9.0

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"] /100 * car_sales["Fuel per 100kM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    4.0             8.9
# 2  Toyota   Blue          32549      3   700000    5.0             8.9
# 3     BMW  Black          11179      5  2200000    4.0             9.0
# 4  Nissan  White         213095      4   350000    5.0             7.8
# 5  Toyota  Green          99213      4   450000    5.0             8.9
# 6   Honda   Blue          45698      4   750000    5.0             9.0
# 7   Honda   Blue          54738      4   700000    5.0             7.8
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             9.0
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         7823.011             7823.011
# 2         2896.861             2896.861
# ...

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    4.0             8.9
# 2  Toyota   Blue          32549      3   700000    5.0             8.9
# 3     BMW  Black          11179      5  2200000    4.0             9.0
# 4  Nissan  White         213095      4   350000    5.0             7.8
# 5  Toyota  Green          99213      4   450000    5.0             8.9
# 6   Honda   Blue          45698      4   750000    5.0             9.0
# 7   Honda   Blue          54738      4   700000    5.0             7.8
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             9.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         7823.011             7823.011                 4
# ...

# %%
car_sales ["Passed road saftey"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    4.0             8.9
# 2  Toyota   Blue          32549      3   700000    5.0             8.9
# 3     BMW  Black          11179      5  2200000    4.0             9.0
# 4  Nissan  White         213095      4   350000    5.0             7.8
# 5  Toyota  Green          99213      4   450000    5.0             8.9
# 6   Honda   Blue          45698      4   750000    5.0             9.0
# 7   Honda   Blue          54738      4   700000    5.0             7.8
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             9.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road saftey
# 0        11253.225            11253.225                 4                True
# ...

# %%
car_sales.drop("Total fuel used",axis=1,inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    4.0             8.9
# 2  Toyota   Blue          32549      3   700000    5.0             8.9
# 3     BMW  Black          11179      5  2200000    4.0             9.0
# 4  Nissan  White         213095      4   350000    5.0             7.8
# 5  Toyota  Green          99213      4   450000    5.0             8.9
# 6   Honda   Blue          45698      4   750000    5.0             9.0
# 7   Honda   Blue          54738      4   700000    5.0             7.8
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             9.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             7823.011                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100kM  \
# 0  Toyota  White      93776.875      4   400000    5.0             7.5
# 1   Honda    Red      54936.875      4   500000    4.0             8.9
# 2  Toyota   Blue      20343.125      3   700000    5.0             8.9
# 3     BMW  Black       6986.875      5  2200000    4.0             9.0
# 4  Nissan  White     133184.375      4   350000    5.0             7.8
# 5  Toyota  Green      62008.125      4   450000    5.0             8.9
# 6   Honda   Blue      28561.250      4   750000    5.0             9.0
# 7   Honda   Blue      34211.250      4   700000    5.0             7.8
# 8  Toyota  White      37500.000      4   625000    5.0             8.7
# 9  Nissan  White      19750.000      4   970000    5.0             9.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             7823.011                 4                True
# ...
