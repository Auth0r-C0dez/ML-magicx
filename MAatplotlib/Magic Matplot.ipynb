# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Intro

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([10,23,21,43,32]);

# %%
x = [3,2,5,4]
y = [44,33,22,55]
plt.plot(x,y);

# %% [markdown]
# ### the above shown methods of ploting a matplotlib is called stateless way of ploting

# %%
#first method of using the professional way
fig = plt.figure()  #creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
# second method 
fig = plt.figure()  #creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data 
plt.show()

# %%
# third method
fig, ax = plt.subplots()
ax.plot(x,y); #ad some days

# %% [markdown]
# ## a quality way to get started with matplotlib

# %%
#1 .import matplotlib and get started
# %matplotlib inline
import matplotlib.pyplot as plt

#2 prepare the data
x = [1,2,3,4]
y = [11,22,33,44]

#3 Set up plot
fig , ax = plt.subplots(figsize=(5,5))  #(width , height)

#4 plot the data
ax.plot(x,y)

#4 customize plot
ax.set(title="simple plot" , 
       xlabel ="ex-axis",
       ylabel ="yai-axis")

#5 save and show the figure
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ### Now we make figures with numpy
#
# We will makew graphs :-
# * Line Plot
# * Scatter plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
#creating some data
x = np.linspace(0,10,100) #start,stop and number of items
x[:10] # this will show the first 10 items
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot the data and create a line plot
fig,ax = plt.subplots() # this line creates the graph or the line plot
ax.plot(x,x**2);

# %%
# creatiing a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# making a plot from a dictionary
nut_butter_prices = {"Almond" : 10,
                     "Peanut": 15,
                     "kaju": 10}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys() , nut_butter_prices.values())
ax.set(title = "My dry fruits",
       ylabel = "Price");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()) , list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplots option 1
fig,((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10,5))
#PLot to each diferent axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
import pandas as pd

# %% [markdown]
# ## Creating a graph from a pre exisitng data frame

# %%
car_sales = pd.read_csv("car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range("1/1/2024",periods = 1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]', '',regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# we remove the last two zeros of the price.
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
import pandas as pd

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2024",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Sale Date",y="Total Sales");

# %% [markdown]
# ## Ploting a bar graph using the produced data frame

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.002260  0.756478  0.249059  0.324772
# 1  0.417826  0.839823  0.957885  0.102639
# 2  0.245841  0.621750  0.717605  0.611429
# 3  0.454391  0.151358  0.967760  0.884257
# 4  0.990589  0.915744  0.775358  0.511746
# 5  0.781031  0.785973  0.924684  0.284369
# 6  0.344594  0.049469  0.105806  0.383557
# 7  0.980578  0.251488  0.557956  0.280135
# 8  0.069766  0.905008  0.563611  0.357125
# 9  0.676432  0.038195  0.114557  0.301330

# %% [markdown]
# ## two of creating a graph are:-

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make",y="Odometer (KM)", kind="bar");

# %%
#creating a histogram with respect to their own frequency
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10); #here bins actually means blocks.

# %%
import pandas as pd

# %% [markdown]
# ## Here we make new graphs using a new data frame

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist();

# %% [markdown]
# ##making a histogram usign all the columns

# %%
heart_disease.plot.hist(figsize=(10,30),subplots = True);

# %% [markdown]
# ## Ploting in the OO nethod

# %%
over_50 = heart_disease[heart_disease["age"] > 50 ]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
fix,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind = 'scatter',
             x='age',
             y='chol',
             c='target',
             ax= ax);

# %% [markdown]
# ## Creating a graph from scratch in OO method

# %%
fig,ax =plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])
ax.set(title="Age and cholesterol levels comparison",
       xlabel="Age",
       ylabel="Cholesterol")
ax.legend(*scatter.legend_elements(),title="Target");
ax.axhline(over_50["chol"].mean(),
           linestyle='--');

# %% [markdown]
# ## Creating 2 plots in one frame i.e. usign the subplots.

# %%
fig,(ax0,ax1) = plt.subplots(nrows =2,
                             ncols=1,
                             figsize=(10,10),
                             sharex=True)
scatter = ax0.scatter(x = over_50["age"],
                      y = over_50["chol"],
                      c = over_50["target"])
ax0.set(title="Age and cholesterol level",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(),title = "Target")
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c= over_50["target"])
ax1.set(title="Age and max heart rate",
        xlabel="Age",
        ylabel="Max heart rate")
ax.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");
fig.suptitle("Heart data analysis",fontsize=16,fontweight="bold");

# %%
fig.savefig("heart-disease-plot.png") #this is how we save the figure

# %% [markdown]
# ## Getting with the other styles of matplotlib

# %%
#checking the other styles mof matplotlib.
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Total Sales"].plot();

# %%
import numpy as np
x = np.random.randn(10,4)
x
# Out:
# array([[-1.20123755,  0.48178209, -0.74842929, -0.17214926],
#        [ 2.0990415 ,  0.70564005,  0.75639509, -0.73099415],
#        [-1.07738573,  0.46462248,  0.23646003, -0.73794945],
#        [ 0.70520936,  2.71793491, -1.50283877, -0.77030104],
#        [ 1.20333478,  0.21697365, -0.79945878, -0.57957135],
#        [ 1.44166356, -1.22425315, -0.03832793,  1.9625233 ],
#        [-2.10353836,  0.80511739,  1.22834772, -0.50475794],
#        [ 0.32431048, -0.01414916,  0.65157514, -2.73585262],
#        [-1.14882064, -0.29615112,  1.54398056, -1.00290111],
#        [ 0.25687541, -0.42061461, -0.99647486, -0.57274416]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -1.201238  0.481782 -0.748429 -0.172149
# 1  2.099042  0.705640  0.756395 -0.730994
# 2 -1.077386  0.464622  0.236460 -0.737949
# 3  0.705209  2.717935 -1.502839 -0.770301
# 4  1.203335  0.216974 -0.799459 -0.579571
# 5  1.441664 -1.224253 -0.038328  1.962523
# 6 -2.103538  0.805117  1.228348 -0.504758
# 7  0.324310 -0.014149  0.651575 -2.735853
# 8 -1.148821 -0.296151  1.543981 -1.002901
# 9  0.256875 -0.420615 -0.996475 -0.572744

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind="bar")
ax.set(title = "Random number dataframes plot",
       xlabel="Row",
       ylabel="column",)
ax.legend().set_visible(True)
